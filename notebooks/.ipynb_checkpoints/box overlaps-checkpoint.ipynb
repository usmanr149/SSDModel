# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %load_ext autoreload
# %autoreload 2

def yoloFormattocv(x1, y1, x2, y2, H, W):
    bbox_width = x2 * W
    bbox_height = y2 * H
    center_x = x1 * W
    center_y = y1 * H

    voc = []

    voc.append(center_x - (bbox_width / 2))
    voc.append(center_y - (bbox_height / 2))
    voc.append(center_x + (bbox_width / 2))
    voc.append(center_y + (bbox_height / 2))

    return [int(v) for v in voc]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
 
# setting path
sys.path.append('../')

# %%
from bbox_utils import *

# %%
feature_map_shapes = [38, 19, 10, 5, 3, 1]
aspect_ratios = [
    [1, 2, 0.5],
    [1, 2, 3, 0.5, 0.333],
    [1, 2, 3, 0.5, 0.333],
    [1, 2, 3, 0.5, 0.333],
    [1, 2, 0.5],
    [1, 2, 0.5]
]
number_of_feature_maps = 6

# %%
prior_boxes = generate_default_boxes(feature_map_shapes, number_of_feature_maps, aspect_ratios)

# %%
boxes = convert_to_box_form(prior_boxes)

# %%
gt_boxes = tf.constant([[
    [0., 0., 0.2, 0.2],
    [0.8, 0.8, 1.0, 0.9]
]])

gt_labels = [[1, 2]]
threshold = 0.5

# %%
gt_boxes_map_to_prior, gt_labels_map_to_prior = match_priors_with_gt(boxes, gt_boxes, gt_labels, threshold)

# %%
gt_labels_map_to_prior
# Out:
# <tf.Tensor: shape=(8732,), dtype=int32, numpy=array([0, 0, 0, ..., 0, 0, 0], dtype=int32)>

# %%
image_width = 300
image_height = 300
gt_color = (100, 100, 0)
color = (255, 0, 0)

image = np.ones((image_width, image_height))

# draw gt_boxes
for gt in gt_boxes:
    start_x, start_y, end_x, end_y = gt.numpy()

    start_x, start_y, end_x, end_y = int(start_x * image_width), int(start_y * image_height), int(end_x * image_width), int(end_y * image_height)
#     print(start_x, start_y, end_x, end_y )
    image = cv2.rectangle(image, [start_x, start_y], [end_x, end_y], gt_color, thickness = 1)
    
for m in tf.math.argmax(union, axis = 0):
    start_x, start_y, end_x, end_y = boxes[m, :].numpy()
    
    start_x, start_y, end_x, end_y = int(start_x * image_width), int(start_y * image_height), int(end_x * image_width), int(end_y * image_height)
    
    image = cv2.rectangle(image, [start_x, start_y], [end_x, end_y], color, thickness = 1)
    
plt.figure(figsize = (20,20))
plt.imshow(image)

# %%
image_width = 300
image_height = 300
gt_color = (100, 100, 0)
color = (255, 0, 0)

image = np.ones((image_width, image_height))

# draw gt_boxes
for gt in gt_boxes:
    start_x, start_y, end_x, end_y = gt.numpy()

    start_x, start_y, end_x, end_y = int(start_x * image_width), int(start_y * image_height), int(end_x * image_width), int(end_y * image_height)
#     print(start_x, start_y, end_x, end_y )
    image = cv2.rectangle(image, [start_x, start_y], [end_x, end_y], gt_color, thickness = 2)

i = 0
for gt in gt_boxes_map_to_prior:
    start_x, start_y, end_x, end_y = gt.numpy()
    
    if (end_x - start_x) > 0 and (end_y - start_y) > 0:
        
        start_x, start_y, end_x, end_y = boxes[i, :].numpy()
    
        start_x, start_y, end_x, end_y = int(start_x * image_width), int(start_y * image_height), int(end_x * image_width), int(end_y * image_height)

        image = cv2.rectangle(image, [start_x, start_y], [end_x, end_y], color, thickness = 1)
    i+=1
    
plt.figure(figsize = (20,20))
plt.imshow(image)

# %%
i = 0
for gt in gt_boxes_map_to_prior:
    start_x, start_y, end_x, end_y = gt.numpy()
    
    if (end_x - start_x) > 0 and (end_y - start_y) > 0:
        
        print(i, gt_labels_map_to_prior[i])
    i+=1
# Out:
# 4992 tf.Tensor(2, shape=(), dtype=int32)
# 5144 tf.Tensor(2, shape=(), dtype=int32)
# 5296 tf.Tensor(2, shape=(), dtype=int32)
# 5448 tf.Tensor(2, shape=(), dtype=int32)
# 5776 tf.Tensor(1, shape=(), dtype=int32)
# 5782 tf.Tensor(1, shape=(), dtype=int32)
# 5783 tf.Tensor(1, shape=(), dtype=int32)
# 5784 tf.Tensor(1, shape=(), dtype=int32)
# 5785 tf.Tensor(1, shape=(), dtype=int32)
# 5788 tf.Tensor(1, shape=(), dtype=int32)
# 5790 tf.Tensor(1, shape=(), dtype=int32)
# 5791 tf.Tensor(1, shape=(), dtype=int32)
# 5890 tf.Tensor(1, shape=(), dtype=int32)
# 5891 tf.Tensor(1, shape=(), dtype=int32)
# 5894 tf.Tensor(1, shape=(), dtype=int32)
# 5895 tf.Tensor(1, shape=(), dtype=int32)
# 5896 tf.Tensor(1, shape=(), dtype=int32)
# 5897 tf.Tensor(1, shape=(), dtype=int32)
# 5898 tf.Tensor(1, shape=(), dtype=int32)
# 5899 tf.Tensor(1, shape=(), dtype=int32)
# 5900 tf.Tensor(1, shape=(), dtype=int32)
# 5901 tf.Tensor(1, shape=(), dtype=int32)
# 5902 tf.Tensor(1, shape=(), dtype=int32)
# 5903 tf.Tensor(1, shape=(), dtype=int32)
# 5904 tf.Tensor(1, shape=(), dtype=int32)
# 5905 tf.Tensor(1, shape=(), dtype=int32)
# 5906 tf.Tensor(1, shape=(), dtype=int32)
# 6004 tf.Tensor(1, shape=(), dtype=int32)
# 6008 tf.Tensor(1, shape=(), dtype=int32)
# 6009 tf.Tensor(1, shape=(), dtype=int32)
# 6010 tf.Tensor(1, shape=(), dtype=int32)
# 6011 tf.Tensor(1, shape=(), dtype=int32)
# 6012 tf.Tensor(1, shape=(), dtype=int32)
# 6014 tf.Tensor(1, shape=(), dtype=int32)
# 6015 tf.Tensor(1, shape=(), dtype=int32)
# 6016 tf.Tensor(1, shape=(), dtype=int32)
# 6017 tf.Tensor(1, shape=(), dtype=int32)
# 6018 tf.Tensor(1, shape=(), dtype=int32)
# 6020 tf.Tensor(1, shape=(), dtype=int32)
# 7698 tf.Tensor(2, shape=(), dtype=int32)
# 7806 tf.Tensor(2, shape=(), dtype=int32)
# 7812 tf.Tensor(2, shape=(), dtype=int32)
# 7813 tf.Tensor(2, shape=(), dtype=int32)
# 7921 tf.Tensor(2, shape=(), dtype=int32)
# 7926 tf.Tensor(2, shape=(), dtype=int32)
# 7927 tf.Tensor(2, shape=(), dtype=int32)
# 7942 tf.Tensor(1, shape=(), dtype=int32)
# 7943 tf.Tensor(1, shape=(), dtype=int32)
# 7944 tf.Tensor(1, shape=(), dtype=int32)
# 7946 tf.Tensor(1, shape=(), dtype=int32)
# 7949 tf.Tensor(1, shape=(), dtype=int32)
# 8003 tf.Tensor(1, shape=(), dtype=int32)

# %%
gt_labels_map_to_prior
# Out:
# <tf.Tensor: shape=(8732,), dtype=int32, numpy=array([0, 0, 0, ..., 0, 0, 0], dtype=int32)>

# %%
labels = tf.one_hot(gt_labels_map_to_prior, 3)

# %%
labels[4992]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0., 0., 1.], dtype=float32)>
